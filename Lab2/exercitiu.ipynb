# %%
import random

bileRosii = 3
bileAlbastre = 4
bileNegre = 2

bileRosiiScoase = 0
urnaBile = ['r', 'r', 'r', 'a', 'a', 'a', 'a', 'n', 'n']

# buna
def addingBileInUrna():
    # global bileRosii
    # global bileAlbastre
    global urnaBile
    
    randomNumberZar = random.randint(1, 6)
    
    if(randomNumberZar == 6):
        # bileRosii += 1
        urnaBile.append('r')
    elif(randomNumberZar == 4 or randomNumberZar == 1):
        # bileAlbastre += 1
        urnaBile.append('a')
    else:
        # bileNegre += 1
        urnaBile.append('n')


def scoatemBilaDinUrna():
    # global bileRosii
    # global bileAlbastre
    # global bileNegre
    global bileRosiiScoase
    
    randomNumberBila = random.randint(0, 9)
    if(urnaBile[randomNumberBila] == 'r'):
        bileRosiiScoase += 1
    
    # if(randomNumberBila[] == 1):
    #     bileRosii -= 1
    #     bileRosiiScoase += 1
    # elif(randomNumberBila == 2):
    #     bileAlbastre -= 1
    # else:
    #     bileNegre -= 1

repetari = 100000

for index in range(0, repetari):
    # global bileRosii
    # global bileAlbastre
    # global bileNegre
    urnaBile = ['r', 'r', 'r', 'a', 'a', 'a', 'a', 'n', 'n']

    # bileRosii = 3
    # bileAlbastre = 4
    # bileNegre = 2

    addingBileInUrna()
    scoatemBilaDinUrna()
    
    # probabilitatea = bileRosii / (bileRosii + bileAlbastre + bileNegre)
    # arrayProbabilitati.append(probabilitatea)

print(bileRosiiScoase / repetari)
# print(sum(arrayProbabilitati) / repetari)




# P(R) = 1/6 adaugare bila rosie
# P(A) = 1/6 adaugare bile albastra
# P(N) = 4/6 adaugare bila neagra
# 1/3 probabilitatea de a extrage o bila

# P (zar prim) = 3 / 10 
# P (zar 6) = 4 /10
# P (zar altu) = 3 / 10
# Out:
# 0.31718
